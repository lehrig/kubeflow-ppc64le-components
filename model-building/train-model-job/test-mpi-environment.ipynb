# %% [markdown]
# # Test: MPI Environment
#
# ## Author
# - Sebastian Lehrig <sebastian.lehrig1@ibm.com>
#
# ## License
# Apache-2.0 License

# %%
# !horovodrun --check-build
# Out:
# Horovod v0.25.0:
#
# Available Frameworks:
#     [X] TensorFlow
#     [X] PyTorch
#     [ ] MXNet
#
# Available Controllers:
#     [X] MPI
#     [ ] Gloo
#
# Available Tensor Operations:
#     [X] NCCL
#     [ ] DDL
#     [ ] CCL
#     [X] MPI
#     [ ] Gloo

# %%
# !mpirun --version
# Out:
# mpirun (Open MPI) 4.1.1
#
# Report bugs to http://www.open-mpi.org/community/help/

# %%
# !mamba list | grep -i 'mpi\|nccl\|cud'
# Out:
# _pytorch_select           2.0                      cuda_2    https://ftp.osuosl.org/pub/open-ce/current
# _tensorflow_select        2.0                      cuda_2    https://ftp.osuosl.org/pub/open-ce/current
# cudatoolkit               11.4.4              h5d40d8d_10    https://ftp.osuosl.org/pub/open-ce/current
# cudnn                     8.3.0_11.4           h5b181e6_1    https://ftp.osuosl.org/pub/open-ce/current
# horovod                   0.25.0          cuda11.4_openmpi_py39_1    https://ftp.osuosl.org/pub/open-ce/current
# mpi                       1.0                     openmpi    defaults
# nccl                      2.12.7               cuda11.4_1    https://ftp.osuosl.org/pub/open-ce/current
# onnxruntime               1.12.1          hf9ee15a_cuda11.4_py39_pb3.19_1    https://ftp.osuosl.org/pub/open-ce/current
# openmpi                   4.1.1                cuda11.4_4    https://ftp.osuosl.org/pub/open-ce/current
# ...

# %%
# !ompi_info
# Out:
# [elyra3-14-1-0:10583] mca_base_component_repository_open: unable to open mca_fbtl_posix: /opt/conda/lib/openmpi/mca_fbtl_posix.so: undefined symbol: mca_common_ompio_progress (ignored)
#                  Package: Open MPI opence@cqls-p9-4.cgrb.oregonstate.local
#                           Distribution
#                 Open MPI: 4.1.1
#   Open MPI repo revision: v4.1.1
#    Open MPI release date: Apr 24, 2021
#                 Open RTE: 4.1.1
#   Open RTE repo revision: v4.1.1
#    Open RTE release date: Apr 24, 2021
#                     OPAL: 4.1.1
#       OPAL repo revision: v4.1.1
#        OPAL release date: Apr 24, 2021
#                  MPI API: 3.1.0
#             Ident string: 4.1.1
#                   Prefix: /opt/conda
#  Configured architecture: powerpc64le-conda-linux-gnu
#           Configure host: cqls-p9-4.cgrb.oregonstate.local
#            Configured by: opence
#            Configured on: Sat Sep 24 07:18:38 UTC 2022
# ...
